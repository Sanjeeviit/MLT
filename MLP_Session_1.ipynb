# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjeeviit/MLT/blob/main/MLP_Session_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

# %%
dataset = load_iris(as_frame = True)

# %%
df = dataset["data"]
df["target"] = dataset["target"]

# %%
df.describe() # df.info()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
? sns.heatmap

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", cbar=True)
plt.title('Correlation Heatmap of Iris Dataset')
plt.show()

# %% [markdown]
# - petal info has high correlation with target

# %%
for feature in df.columns[:-1]:
    plt.figure(figsize=(6, 4))
    sns.boxplot(data=df, x='target', y=feature, palette='Set3')
    plt.title(f'{feature} Distribution by Target Class')
    plt.show()
# Out:
# <ipython-input-31-9b658e6dfbca>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='target', y=feature, palette='Set3')
# <ipython-input-31-9b658e6dfbca>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='target', y=feature, palette='Set3')
# <ipython-input-31-9b658e6dfbca>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='target', y=feature, palette='Set3')
# <ipython-input-31-9b658e6dfbca>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='target', y=feature, palette='Set3')

# %%
df.iloc[:, :-1].hist(figsize=(10, 8), bins=15, color='skyblue', edgecolor='black')
plt.suptitle('Feature Histograms', fontsize=16)
plt.show()

# %%
sns.scatterplot(data=df, x='sepal length (cm)', y='petal length (cm)', hue='target', palette='Set1')
plt.title('Sepal Length vs Petal Length by Target Class')
plt.show()

# %%
import matplotlib.pyplot as plt


target_counts = df['target'].value_counts()
target_labels = [f'Class {i}' for i in target_counts.index]

plt.figure(figsize=(6, 6))
plt.pie(target_counts, labels=target_labels, autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'coral'])
plt.title('Target Class Distribution')
plt.show()

# %%
class_0 = df[df['target'] == 0]['sepal length (cm)'].sum()
class_1 = df[df['target'] == 1]['sepal length (cm)'].sum()
class_2 = df[df['target'] == 2]['sepal length (cm)'].sum()

sepal_length_sums = [class_0, class_1, class_2]
labels = ['Class 0', 'Class 1', 'Class 2']

plt.figure(figsize=(6, 6))
plt.pie(sepal_length_sums, labels=labels, autopct='%1.1f%%', colors=['gold', 'lightblue', 'pink'])
plt.title('Sepal Length Distribution by Class')
plt.show()

# %%
? sns.violinplot

# %%
sns.violinplot(data=df, x='target', y='petal width (cm)', palette='muted')
plt.title('Violin Plot of Petal Width by Target Class')
plt.show()
# Out:
# <ipython-input-36-11afff042003>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='target', y='petal width (cm)', palette='muted')

# %%
df.groupby('target')['sepal length (cm)'].mean().plot(kind='bar', color=['skyblue', 'lightgreen', 'coral'])
plt.title('Average Sepal Length by Target Class')
plt.xlabel('Target Class')
plt.ylabel('Average Sepal Length (cm)')
plt.show()

# %% [markdown]
# ### DOUBTS

# %%
y_pred = model.predict(X_test)

# %%
submission = pd.DataFrame({
    "id" : np.arange(0,10000),
    "target" : y_pred,
})
submission.to_csv('submission.csv',index = False)
